# %% [markdown]
# #### 데이터전처리_로지스틱분류실험 251029

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("./credit_risk_dataset.csv") 
df.head()
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          22          59000                  RENT              123.0
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0    PERSONAL          D      35000          16.02            1
# 1   EDUCATION          B       1000          11.14            0
# 2     MEDICAL          C       5500          12.87            1
# 3     MEDICAL          C      35000          15.23            1
# 4     MEDICAL          C      35000          14.27            1
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 0                 0.59                         Y                           3
# 1                 0.10                         N                           2
# 2                 0.57                         N                           3
# 3                 0.53                         N                           2
# 4                 0.55                         Y                           4

# %%
df.shape
# Out:
# (32581, 12)

# %% [markdown]
# #### 상관관계 시각화

# %%
corr_x = df.select_dtypes(['float', 'int']).corr()

# %%
plt.figure(figsize=(6, 6))  
sns.heatmap(corr_x, annot=True, cmap='Reds')  
plt.show()

# %% [markdown]
# #### 상관계수 높은 컬럼 시각화

# %%
plt.figure(figsize=(5,3))
sns.scatterplot(data=df, x='person_age', y='cb_person_cred_hist_length', color='cornflowerblue')  
plt.show()

# %%
print("미리 봐뒀던 loan_int_rate 제거할거고 (사후적인 변수라서), \n상관계수 높은 변수는 제거할지 말지 고민")
# Out:
# 미리 봐뒀던 loan_int_rate 제거할거고 (사후적인 변수라서),
# 상관계수 높은 변수는 제거할지 말지 고민

# %%
print("loan_int_rate랑 loan_grade(target)을 ANOVA나 Kruskal 검정 해봐야하나? ")
# Out:
# loan_int_rate랑 loan_grade(target)을 ANOVA나 Kruskal 검정 해봐야하나?

# %%
df = df.drop(['loan_int_rate'], axis=1) 
df.head()
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          22          59000                  RENT              123.0
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
#
#   loan_intent loan_grade  loan_amnt  loan_status  loan_percent_income  \
# 0    PERSONAL          D      35000            1                 0.59
# 1   EDUCATION          B       1000            0                 0.10
# 2     MEDICAL          C       5500            1                 0.57
# 3     MEDICAL          C      35000            1                 0.53
# 4     MEDICAL          C      35000            1                 0.55
#
#   cb_person_default_on_file  cb_person_cred_hist_length
# 0                         Y                           3
# 1                         N                           2
# 2                         N                           3
# 3                         N                           2
# 4                         Y                           4

# %% [markdown]
# #### 결측치 확인 및 채워넣기

# %%
df.isnull().sum()
# Out:
# person_age                      0
# person_income                   0
# person_home_ownership           0
# person_emp_length             895
# loan_intent                     0
# loan_grade                      0
# loan_amnt                       0
# loan_status                     0
# loan_percent_income             0
# cb_person_default_on_file       0
# cb_person_cred_hist_length      0
# dtype: int64

# %%
df = df.fillna(0)
df.isnull().sum()
# Out:
# person_age                    0
# person_income                 0
# person_home_ownership         0
# person_emp_length             0
# loan_intent                   0
# loan_grade                    0
# loan_amnt                     0
# loan_status                   0
# loan_percent_income           0
# cb_person_default_on_file     0
# cb_person_cred_hist_length    0
# dtype: int64

# %%
df.select_dtypes('object').head()
# Out:
#   person_home_ownership loan_intent loan_grade cb_person_default_on_file
# 0                  RENT    PERSONAL          D                         Y
# 1                   OWN   EDUCATION          B                         N
# 2              MORTGAGE     MEDICAL          C                         N
# 3                  RENT     MEDICAL          C                         N
# 4                  RENT     MEDICAL          C                         Y

# %% [markdown]
# #### 데이터 나누기

# %%
df.columns
# Out:
# Index(['person_age', 'person_income', 'person_home_ownership',
#        'person_emp_length', 'loan_intent', 'loan_grade', 'loan_amnt',
#        'loan_status', 'loan_percent_income', 'cb_person_default_on_file',
#        'cb_person_cred_hist_length'],
#       dtype='object')

# %%
features = list(df.columns)
features.remove('loan_grade')

X = df[features]
y = df['loan_grade']

# %% [markdown]
# #### 명목형변수 변경
# - 우선은 one-hot-encoding으로 / label encoding도 고려해보기

# %%
X.select_dtypes('object').head()
# Out:
#   person_home_ownership loan_intent cb_person_default_on_file
# 0                  RENT    PERSONAL                         Y
# 1                   OWN   EDUCATION                         N
# 2              MORTGAGE     MEDICAL                         N
# 3                  RENT     MEDICAL                         N
# 4                  RENT     MEDICAL                         Y

# %%
# one-hot encoding
# X = pd.get_dummies(X, dtype=float)
# X.shape
# Out:
# (32581, 19)

# %%
# label encoding
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
X['person_home_ownership'] = encoder.fit_transform(X['person_home_ownership'])
# Out:
# array([3, 2, 0, ..., 3, 0, 3])

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32581 entries, 0 to 32580
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   person_age                      32581 non-null  int64
#  1   person_income                   32581 non-null  int64
#  2   person_emp_length               32581 non-null  float64
#  3   loan_amnt                       32581 non-null  int64
#  4   loan_status                     32581 non-null  int64
#  5   loan_percent_income             32581 non-null  float64
#  6   cb_person_cred_hist_length      32581 non-null  int64
#  7   person_home_ownership_MORTGAGE  32581 non-null  float64
#  8   person_home_ownership_OTHER     32581 non-null  float64
#  9   person_home_ownership_OWN       32581 non-null  float64
#  10  person_home_ownership_RENT      32581 non-null  float64
#  11  loan_intent_DEBTCONSOLIDATION   32581 non-null  float64
#  12  loan_intent_EDUCATION           32581 non-null  float64
#  13  loan_intent_HOMEIMPROVEMENT     32581 non-null  float64
#  14  loan_intent_MEDICAL             32581 non-null  float64
#  15  loan_intent_PERSONAL            32581 non-null  float64
#  16  loan_intent_VENTURE             32581 non-null  float64
#  17  cb_person_default_on_file_N     32581 non-null  float64
#  18  cb_person_default_on_file_Y     32581 non-null  float64
# dtypes: float64(14), int64(5)
# memory usage: 4.7 MB

# %%
# 트레이닝/테스트 데이터 분할 
from sklearn.model_selection import train_test_split
X_tn, X_te, y_tn, y_te = train_test_split(X, y, random_state=0, stratify=y)

# %%
# 데이터 표준화
from sklearn.preprocessing import StandardScaler 
std_scale = StandardScaler()
std_scale.fit(X_tn)
X_tn_std = std_scale.transform(X_tn)
X_te_std = std_scale.transform(X_te)

# %% [markdown]
# #### 로지스틱 모델 돌려보기

# %%
# 로지스틱 회귀분석 (L2 제약식 적용)
from sklearn.linear_model import LogisticRegression
clf_logi_l2 = LogisticRegression(penalty='l2')
clf_logi_l2.fit(X_tn_std, y_tn)
# Out:
# LogisticRegression()

# %%
# 로지스틱 회귀분석 모형 (L2 제약식 적용) 추정 계수
print(clf_logi_l2.coef_)
print(clf_logi_l2.intercept_)
# Out:
# [[ 3.48494514e-02  1.86118111e-01  6.30031113e-02 -7.37454511e-01
#   -1.03602323e+00  4.78124018e-01 -9.33230167e-02  8.41116582e-02
#    7.03128955e-03 -1.19009631e-01 -1.94280768e-02  9.19569545e-02
#   -1.56738804e-02 -2.32905439e-02  6.38372847e-02 -1.45444022e-02
#   -1.03407937e-01  1.38890733e+00 -1.38890733e+00]
#  [ 2.96233965e-02  1.43857278e-01  1.31327643e-02 -3.70759105e-01
#   -8.52384514e-01  3.82521256e-01 -7.34503665e-02 -4.76510952e-02
#    1.16788135e-02 -1.22739588e-01  1.11752081e-01  6.12472462e-02
#   -2.51155390e-02 -1.69455374e-02  7.03874083e-02  8.82189987e-04
#   -9.12490439e-02  1.38167201e+00 -1.38167201e+00]
#  [ 2.05930702e-02  1.72899246e-01 -3.46187434e-02 -4.83010331e-01
#   -7.11246061e-01  3.59824763e-01 -1.21436578e-02 -6.46942604e-02
#    1.67958701e-03 -1.16658037e-01  1.26332977e-01  8.89990491e-02
#    1.00708380e-03 -1.26432353e-02  6.92830039e-02 -2.85044198e-02
#   -1.18612700e-01 -5.62357390e-01  5.62357390e-01]
#  [ 2.33963131e-02 -9.95242470e-02  4.52964728e-02  6.56892074e-02
#    2.00712188e-01 -1.75586703e-01 -2.11154045e-02 -5.43435443e-02
#    2.77556970e-02  2.16104007e-02  3.88311889e-02  6.06218631e-03
#    1.74565093e-02  4.90798430e-03 -1.38230728e-02  2.55010360e-02
#   -3.91414892e-02 -5.68422492e-01  5.68422492e-01]
#  [ 1.32142903e-01 -1.30613920e-02 -6.39216372e-02  2.91220399e-01
#    3.27687218e-01 -2.65226937e-01 -1.40682857e-01 -5.49770678e-02
#    3.26381766e-02 -1.17246743e-02  5.68836164e-02 -5.24802114e-02
#    4.75818678e-02  3.28001576e-02 -1.67576058e-02 -4.18593142e-02
#    3.18521605e-02 -5.39936106e-01  5.39936106e-01]
#  [ 8.11300294e-02 -1.63651950e-01 -1.31362833e-01  5.27411915e-01
#    4.27858711e-01 -3.45962450e-01 -1.95186570e-02  4.18986717e-02
#    6.80807018e-02  1.27076814e-02 -5.54616300e-02  2.39085261e-02
#    1.56811107e-02 -2.01886680e-02  5.32177124e-03 -5.22169113e-02
#    2.34273662e-02 -5.42189292e-01  5.42189292e-01]
#  [-3.21735164e-01 -2.26637046e-01  1.08470866e-01  7.06902425e-01
#    1.64339569e+00 -4.33693947e-01  3.60233959e-01  9.56556378e-02
#   -1.48864265e-01  3.35813848e-01 -2.58910156e-01 -2.19693751e-01
#   -4.09371521e-02  3.53598427e-02 -1.78248790e-01  1.10741822e-01
#    2.97131643e-01 -5.57674064e-01  5.57674064e-01]]
# [ 1.62070765  1.67182038  2.28909727  1.3515524  -0.12654414 -1.72330291
#  -5.08333064]

# %%
# 예측
pred_logistic = clf_logi_l2.predict(X_te_std)
print(pred_logistic)
# Out:
# ['B' 'A' 'A' ... 'D' 'B' 'A']

# %%
# confusion matrix 확인
from sklearn.metrics import confusion_matrix
conf_matrix = confusion_matrix(y_te, pred_logistic)
print(conf_matrix)
# Out:
# [[1781  883    0   30    0    0    0]
#  [1239 1320    0   54    0    0    0]
#  [ 362  420  684  149    0    0    0]
#  [ 118  273  213  303    0    0    0]
#  [  26   79   49   87    0    0    0]
#  [   3   26    9   22    0    0    0]
#  [   1    1    0   14    0    0    0]]

# %%
# 분류 레포트 확인
from sklearn.metrics import classification_report
class_report = classification_report(y_te, pred_logistic)
print(class_report)
# Out:
#               precision    recall  f1-score   support
#
#            A       0.50      0.66      0.57      2694
#            B       0.44      0.51      0.47      2613
#            C       0.72      0.42      0.53      1615
#            D       0.46      0.33      0.39       907
#            E       0.00      0.00      0.00       241
#            F       0.00      0.00      0.00        60
#            G       0.00      0.00      0.00        16
#
#     accuracy                           0.50      8146
#    macro avg       0.30      0.27      0.28      8146
# weighted avg       0.50      0.50      0.49      8146

# %%
print("loan_int_rate변수 제거하니까 성능 엄청낮음.\n그리고 클래스별로 비율이 달라서인지 undersampling이 필요할 것 같음.")
print("클래스가 다양하니까 데이터도 더 많이 필요할것같고, one-hot encoding보다는 labelencoder가 필요할 것 같음.")
# Out:
# loan_int_rate변수 제거하니까 성능 엄청낮음.
# 그리고 클래스별로 비율이 달라서인지 undersampling이 필요할 것 같음.
# 클래스가 다양하니까 데이터도 더 많이 필요할것같고, one-hot encoding보다는 labelencoder가 필요할 것 같음.
