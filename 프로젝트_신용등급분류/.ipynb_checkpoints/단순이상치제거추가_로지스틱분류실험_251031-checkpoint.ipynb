# %% [markdown]
# #### 이상치제거추가_데이터전처리_로지스틱분류실험 251103

# %% [markdown]
# - 251029의 실험결과가 너무 안좋아서 추가 데이터 전처리 필요할듯

# %% [markdown]
# - 이상치 제거 방법: IQR, One-Class SVM, Local Outlier Factor, Isolation Forest 등 여러가지가 있는듯

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("./credit_risk_dataset.csv") 
df.head()
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          22          59000                  RENT              123.0
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0    PERSONAL          D      35000          16.02            1
# 1   EDUCATION          B       1000          11.14            0
# 2     MEDICAL          C       5500          12.87            1
# 3     MEDICAL          C      35000          15.23            1
# 4     MEDICAL          C      35000          14.27            1
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 0                 0.59                         Y                           3
# 1                 0.10                         N                           2
# 2                 0.57                         N                           3
# 3                 0.53                         N                           2
# 4                 0.55                         Y                           4

# %%
df.shape
# Out:
# (32581, 12)

# %% [markdown]
# - loan_int_rate 변수 제거

# %%
corr_x = df.select_dtypes(['float', 'int']).corr()

# %%
df = df.drop(['loan_int_rate'], axis=1) 
df.head()
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          22          59000                  RENT              123.0
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
#
#   loan_intent loan_grade  loan_amnt  loan_status  loan_percent_income  \
# 0    PERSONAL          D      35000            1                 0.59
# 1   EDUCATION          B       1000            0                 0.10
# 2     MEDICAL          C       5500            1                 0.57
# 3     MEDICAL          C      35000            1                 0.53
# 4     MEDICAL          C      35000            1                 0.55
#
#   cb_person_default_on_file  cb_person_cred_hist_length
# 0                         Y                           3
# 1                         N                           2
# 2                         N                           3
# 3                         N                           2
# 4                         Y                           4

# %% [markdown]
# #### 결측치 확인 및 채워넣기

# %%
df.isnull().sum()
# Out:
# person_age                      0
# person_income                   0
# person_home_ownership           0
# person_emp_length             895
# loan_intent                     0
# loan_grade                      0
# loan_amnt                       0
# loan_status                     0
# loan_percent_income             0
# cb_person_default_on_file       0
# cb_person_cred_hist_length      0
# dtype: int64

# %%
df = df.fillna(0)
df.isnull().sum()
# Out:
# person_age                    0
# person_income                 0
# person_home_ownership         0
# person_emp_length             0
# loan_intent                   0
# loan_grade                    0
# loan_amnt                     0
# loan_status                   0
# loan_percent_income           0
# cb_person_default_on_file     0
# cb_person_cred_hist_length    0
# dtype: int64

# %%
df.select_dtypes('object').head()
# Out:
#   person_home_ownership loan_intent loan_grade cb_person_default_on_file
# 0                  RENT    PERSONAL          D                         Y
# 1                   OWN   EDUCATION          B                         N
# 2              MORTGAGE     MEDICAL          C                         N
# 3                  RENT     MEDICAL          C                         N
# 4                  RENT     MEDICAL          C                         Y

# %% [markdown]
# #### 이상치 box plot 시각화

# %%
df.columns
# Out:
# Index(['person_age', 'person_income', 'person_home_ownership',
#        'person_emp_length', 'loan_intent', 'loan_grade', 'loan_amnt',
#        'loan_status', 'loan_percent_income', 'cb_person_default_on_file',
#        'cb_person_cred_hist_length'],
#       dtype='object')

# %%
df.select_dtypes('number').head()
# Out:
#    person_age  person_income  person_emp_length  loan_amnt  loan_status  \
# 0          22          59000              123.0      35000            1
# 1          21           9600                5.0       1000            0
# 2          25           9600                1.0       5500            1
# 3          23          65500                4.0      35000            1
# 4          24          54400                8.0      35000            1
#
#    loan_percent_income  cb_person_cred_hist_length
# 0                 0.59                           3
# 1                 0.10                           2
# 2                 0.57                           3
# 3                 0.53                           2
# 4                 0.55                           4

# %%
now_columns = list(df.select_dtypes('number').columns)
now_columns.remove('loan_status')
now_columns
# Out:
# ['person_age',
#  'person_income',
#  'person_emp_length',
#  'loan_amnt',
#  'loan_percent_income',
#  'cb_person_cred_hist_length']

# %%
print("loan_status는 0,1인 변수이므로 이것을 제외하고 시각화.")
# Out:
# loan_status는 0,1인 변수이므로 이것을 제외하고 시각화.

# %%
fig, axes = plt.subplots(3, 2, figsize=(12, 6))
axes = axes.flatten()

for i, col in enumerate(now_columns):
    sns.boxplot(data=df, y = col, ax=axes[i], color='cornflowerblue')
    axes[i].set_title(f'{col}')

plt.tight_layout()
plt.show()

# %%
print("위 6개 컬럼들은 다 이상치가 있어보이므로 제거 필요. ")
# Out:
# 위 6개 컬럼들은 다 이상치가 있어보이므로 제거 필요.

# %% [markdown]
# #### 값 파악
# - 이상치의 보수적인 제거

# %%
# person_age
print(df['person_age'].max())
print(df[df['person_age'] > 100].shape[0])
print(df[df['person_age'] > 100].loan_grade.unique())  # 데이터 많은쪽 클래스라 제거해도 될듯 
print("B,C는 데이터 많은쪽 클래스라 100세 이상인 데이터 제거해도 될듯. ")
# Out:
# 144
# 5
# ['C' 'B']
# B,C는 데이터 많은쪽 클래스라 100세 이상인 데이터 제거해도 될듯.

# %%
# person_income 
print(df['person_income'].max())
print(df['person_income'].sort_values(ascending=False))
print(df[df['person_income'] == 6000000].loan_grade.unique())
print("C는 데이터 많은쪽 클래스라 데이터 제거해도 될듯. ")
# Out:
# 6000000
# 32297    6000000
# 30049    2039784
# 32546    1900000
# 32497    1782000
# 31924    1440000
#           ...
# 15960       4800
# 15963       4200
# 27896       4200
# 15964       4080
# 31930       4000
# Name: person_income, Length: 32581, dtype: int64
# ['C']
# C는 데이터 많은쪽 클래스라 데이터 제거해도 될듯.

# %%
# person_emp_length
print(df['person_emp_length'].max())
print(df['person_emp_length'].sort_values(ascending=False))
print(df[df['person_emp_length'] == 123].loan_grade.unique())
print("D클래스를 포함하고 있긴 하지만 고용기간이 123년은 너무 outlier라서 데이터 제거.")
# Out:
# 123.0
# 210      123.0
# 0        123.0
# 32355     41.0
# 32515     38.0
# 32428     34.0
#          ...
# 11548      0.0
# 11544      0.0
# 11567      0.0
# 11566      0.0
# 32528      0.0
# Name: person_emp_length, Length: 32581, dtype: float64
# ['D' 'A']
# D클래스를 포함하고 있긴 하지만 고용기간이 123년은 너무 outlier라서 데이터 제거.

# %%
# person_income
print(df['person_income'].max())
print(df['person_income'].sort_values(ascending=False))
df[df['person_income'] == 2039784]
print("income이 높고, venture 투자를 해서 loan_grade가 C인듯. 데이터 안빼고 일단 유지.")
# Out:
# 6000000
# 32297    6000000
# 30049    2039784
# 32546    1900000
# 32497    1782000
# 31924    1440000
#           ...
# 15960       4800
# 15963       4200
# 27896       4200
# 15964       4080
# 31930       4000
# Name: person_income, Length: 32581, dtype: int64
# income이 높고, venture 투자를 해서 loan_grade가 C인듯. 데이터 안빼고 일단 유지.

# %% [markdown]
# #### 데이터 제거

# %%
print(df.shape)
df = df[df['person_age'] <= 100]
print(df.shape)  # 제거 후 데이터 개수
# Out:
# (32581, 11)
# (32576, 11)

# %%
print(df.shape) 
df = df[df['person_income'] != 6000000]
print(df.shape)  # 제거 후 데이터 개수 
print('person_age에서 제거된듯')
# Out:
# (32576, 11)
# (32576, 11)
# person_age에서 제거된듯

# %%
print(df[df['person_emp_length'] == 123])
print('person_age가 21,22인데 고용기간이 123년이라니 잘못된 데이터 같음')
# Out:
#      person_age  person_income person_home_ownership  person_emp_length  \
# 0            22          59000                  RENT              123.0
# 210          21         192000              MORTGAGE              123.0
#
#     loan_intent loan_grade  loan_amnt  loan_status  loan_percent_income  \
# 0      PERSONAL          D      35000            1                 0.59
# 210     VENTURE          A      20000            0                 0.10
#
#     cb_person_default_on_file  cb_person_cred_hist_length
# 0                           Y                           3
# 210                         N                           4
# person_age가 21,22인데 고용기간이 123년이라니 잘못된 데이터 같음

# %%
print(df.shape) 
df = df[df['person_emp_length'] != 123]
print(df.shape)  # 제거 후 데이터 개수
# Out:
# (32576, 11)
# (32574, 11)

# %% [markdown]
# #### 데이터 나누기

# %%
df.columns
# Out:
# Index(['person_age', 'person_income', 'person_home_ownership',
#        'person_emp_length', 'loan_intent', 'loan_grade', 'loan_amnt',
#        'loan_status', 'loan_percent_income', 'cb_person_default_on_file',
#        'cb_person_cred_hist_length'],
#       dtype='object')

# %%
features = list(df.columns)
features.remove('loan_grade')

X = df[features]
y = df['loan_grade']

# %% [markdown]
# #### 명목형변수 변경
# - 우선은 one-hot-encoding으로 / label encoding도 고려해보기

# %%
X.select_dtypes('object').head()
# Out:
#   person_home_ownership loan_intent cb_person_default_on_file
# 1                   OWN   EDUCATION                         N
# 2              MORTGAGE     MEDICAL                         N
# 3                  RENT     MEDICAL                         N
# 4                  RENT     MEDICAL                         Y
# 5                   OWN     VENTURE                         N

# %%
# # one-hot encoding
# X = pd.get_dummies(X, dtype=float)
# X.shape
# Out:
# (32574, 19)

# %%
# label encoding
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
X['person_home_ownership'] = encoder.fit_transform(X['person_home_ownership'])
X['loan_intent'] = encoder.fit_transform(X['loan_intent'])
X['cb_person_default_on_file'] = encoder.fit_transform(X['cb_person_default_on_file'])

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32574 entries, 1 to 32580
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   person_age                      32574 non-null  int64
#  1   person_income                   32574 non-null  int64
#  2   person_emp_length               32574 non-null  float64
#  3   loan_amnt                       32574 non-null  int64
#  4   loan_status                     32574 non-null  int64
#  5   loan_percent_income             32574 non-null  float64
#  6   cb_person_cred_hist_length      32574 non-null  int64
#  7   person_home_ownership_MORTGAGE  32574 non-null  float64
#  8   person_home_ownership_OTHER     32574 non-null  float64
#  9   person_home_ownership_OWN       32574 non-null  float64
#  10  person_home_ownership_RENT      32574 non-null  float64
#  11  loan_intent_DEBTCONSOLIDATION   32574 non-null  float64
#  12  loan_intent_EDUCATION           32574 non-null  float64
#  13  loan_intent_HOMEIMPROVEMENT     32574 non-null  float64
#  14  loan_intent_MEDICAL             32574 non-null  float64
#  15  loan_intent_PERSONAL            32574 non-null  float64
#  16  loan_intent_VENTURE             32574 non-null  float64
#  17  cb_person_default_on_file_N     32574 non-null  float64
#  18  cb_person_default_on_file_Y     32574 non-null  float64
# dtypes: float64(14), int64(5)
# memory usage: 5.0 MB

# %%
# 트레이닝/테스트 데이터 분할 
from sklearn.model_selection import train_test_split
X_tn, X_te, y_tn, y_te = train_test_split(X, y, random_state=0, stratify=y)

# %%
# 데이터 표준화
from sklearn.preprocessing import StandardScaler 
std_scale = StandardScaler()
std_scale.fit(X_tn)
X_tn_std = std_scale.transform(X_tn)
X_te_std = std_scale.transform(X_te)

# %%
y_tn.shape
# Out:
# (24430,)

# %%
df_tmp = pd.concat([pd.DataFrame(X_tn_std, columns=X.columns), pd.Series(y_tn)], axis=1)
df_tmp.head()
# Out:
#    person_age  person_income  person_emp_length  loan_amnt  loan_status  \
# 0   -0.121577       0.059186           1.566162  -1.116323    -0.529336
# 1   -0.926924      -0.668859           0.334413  -0.066463    -0.529336
# 2   -0.604785      -0.108824           1.073462  -1.274197    -0.529336
# 3   -0.443715      -0.512050          -0.650987  -0.879512    -0.529336
# 4    0.039493       0.115190           0.334413   0.857099    -0.529336
#
#    loan_percent_income  cb_person_cred_hist_length  \
# 0            -1.217444                    0.531760
# 1             1.212731                   -0.940436
# 2            -1.310913                   -0.940436
# 3            -0.656635                   -0.449704
# 4             0.371516                    0.041028
#
#    person_home_ownership_MORTGAGE  person_home_ownership_OTHER  \
# 0                       -0.836702                    -0.057677
# 1                       -0.836702                    -0.057677
# 2                        1.195169                    -0.057677
# 3                       -0.836702                    -0.057677
# 4                       -0.836702                    -0.057677
#
#    person_home_ownership_OWN  person_home_ownership_RENT  \
# 0                  -0.294359                    0.989737
# 1                  -0.294359                    0.989737
# 2                  -0.294359                   -1.010369
# 3                  -0.294359                    0.989737
# 4                  -0.294359                    0.989737
#
#    loan_intent_DEBTCONSOLIDATION  loan_intent_EDUCATION  \
# 0                      -0.437379              -0.497824
# 1                      -0.437379              -0.497824
# 2                      -0.437379              -0.497824
# 3                      -0.437379               2.008740
# 4                      -0.437379              -0.497824
#
#    loan_intent_HOMEIMPROVEMENT  loan_intent_MEDICAL  loan_intent_PERSONAL  \
# 0                    -0.352568            -0.473361             -0.452432
# 1                    -0.352568             2.112553             -0.452432
# 2                     2.836335            -0.473361             -0.452432
# 3                    -0.352568            -0.473361             -0.452432
# 4                    -0.352568             2.112553             -0.452432
#
#    loan_intent_VENTURE  cb_person_default_on_file_N  \
# 0             2.154235                     0.462181
# 1            -0.464202                     0.462181
# 2            -0.464202                     0.462181
# 3            -0.464202                     0.462181
# 4            -0.464202                     0.462181
#
#    cb_person_default_on_file_Y loan_grade
# 0                    -0.462181        NaN
# 1                    -0.462181        NaN
# 2                    -0.462181          C
# 3                    -0.462181          C
# 4                    -0.462181          C

# %%
df_tmp.shape
# Out:
# (30580, 20)

# %%
x_cols = list(df.columns)
x_cols.remove('loan_grade')

# %%
len(x_cols)
# Out:
# 10

# %%
fig, axes = plt.subplots(5, 2, figsize=(12, 12))
axes = axes.flatten()

for i, col in enumerate(x_cols):
    sns.histplot(data=df_tmp, x=col, hue='loan_grade', bins=20, kde=True, ax=axes[i], color='cornflowerblue')
    axes[i].set_title(f'{col} Histogram')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 로지스틱 모델 돌려보기

# %%
# 로지스틱 회귀분석 (L2 제약식 적용)
from sklearn.linear_model import LogisticRegression
clf_logi_l2 = LogisticRegression(penalty='l2')
clf_logi_l2.fit(X_tn_std, y_tn)
# Out:
# LogisticRegression()

# %%
# 로지스틱 회귀분석 모형 (L2 제약식 적용) 추정 계수
print(clf_logi_l2.coef_)
print(clf_logi_l2.intercept_)
# Out:
# [[ 3.16108714e-02  1.71718812e-01  2.73475117e-02 -7.58460614e-01
#   -1.03421795e+00  4.93715944e-01 -7.44279510e-02  1.09792826e-01
#   -5.48939604e-03 -1.23335071e-01 -4.06219297e-02  8.56100200e-02
#   -2.08362983e-02 -1.91032163e-02  6.72744748e-02 -1.97473757e-02
#   -9.35501640e-02  1.39434855e+00 -1.39434855e+00]
#  [ 1.05331549e-02  1.36732991e-01 -1.41470801e-02 -4.08668342e-01
#   -8.64861956e-01  4.27863268e-01 -4.27723304e-02 -3.46398737e-02
#    1.92035114e-02 -1.41325545e-01  1.08461010e-01  5.93058608e-02
#   -3.16203940e-02 -6.30238275e-03  7.38774408e-02 -4.42079945e-03
#   -8.92660393e-02  1.38573036e+00 -1.38573036e+00]
#  [ 2.71734000e-02  9.53761634e-02 -5.40407482e-02 -4.41543604e-01
#   -6.90757956e-01  3.21434519e-01 -1.10915369e-02 -5.45288128e-02
#    3.24678229e-04 -1.15970018e-01  1.16471958e-01  8.82758646e-02
#    5.54129284e-03 -2.23478804e-02  7.76125630e-02 -4.60880838e-02
#   -1.05568973e-01 -5.56142666e-01  5.56142666e-01]
#  [ 1.45156618e-02 -1.13886938e-01  2.62938930e-02  1.01733141e-01
#    2.06377654e-01 -2.24228021e-01 -1.56449704e-02 -6.82079859e-02
#    3.25396118e-02  3.22869267e-02  4.59072020e-02  1.04949439e-02
#    1.00017649e-02  3.45094560e-03 -1.31577912e-02  2.85012413e-02
#   -3.80750936e-02 -5.69538819e-01  5.69538819e-01]
#  [ 1.26227434e-01  1.79063793e-02 -8.31475513e-02  2.67536825e-01
#    3.34746238e-01 -2.39511492e-01 -1.34160131e-01 -4.77238165e-02
#    2.86657809e-02 -8.30376290e-03  4.81808330e-02 -5.15595113e-02
#    4.58448495e-02  3.00459242e-02 -2.56549013e-02 -3.26216643e-02
#    3.50612996e-02 -5.44141725e-01  5.44141725e-01]
#  [ 1.00281779e-01 -1.18219248e-01 -1.51075646e-01  5.32304396e-01
#    4.39458740e-01 -3.54106699e-01 -3.58041767e-02  4.09303701e-02
#    6.78991399e-02  1.39753042e-02 -5.56692377e-02  1.98248234e-02
#    1.72538978e-02 -1.95616517e-02  3.45211385e-03 -5.22892515e-02
#    2.69041119e-02 -5.44396982e-01  5.44396982e-01]
#  [-3.10342302e-01 -1.89628159e-01  2.48769621e-01  7.07098199e-01
#    1.60925523e+00 -4.25167518e-01  3.13901096e-01  5.43772932e-02
#   -1.43143326e-01  3.42672165e-01 -2.22729836e-01 -2.11952001e-01
#   -2.61851128e-02  3.38182614e-02 -1.83403900e-01  1.26665933e-01
#    2.64494859e-01 -5.65858719e-01  5.65858719e-01]]
# [ 1.61823629  1.67102785  2.29290628  1.3426662  -0.13101212 -1.74239301
#  -5.05143147]

# %%
# 예측
pred_logistic = clf_logi_l2.predict(X_te_std)
print(pred_logistic)
# Out:
# ['B' 'B' 'A' ... 'D' 'C' 'B']

# %%
# confusion matrix 확인
from sklearn.metrics import confusion_matrix
conf_matrix = confusion_matrix(y_te, pred_logistic)
print(conf_matrix)
# Out:
# [[1641 1014    0   39    0    0    0]
#  [1190 1355    0   67    0    0    0]
#  [ 353  422  675  164    0    0    0]
#  [ 142  248  215  300    2    0    0]
#  [  24   78   49   90    0    0    0]
#  [   3   26    9   21    1    0    0]
#  [   1    1    0   14    0    0    0]]

# %%
labels = sorted(df['loan_grade'].unique())
print(labels)

plt.figure(figsize=(4,4))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', 
            xticklabels=labels, yticklabels=labels, 
            linewidths=0.5, cbar=False, square=True)

plt.title('Confusion Matrix', fontsize=14)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
# 분류 레포트 확인
from sklearn.metrics import classification_report
class_report = classification_report(y_te, pred_logistic)
print(class_report)
# Out:
#               precision    recall  f1-score   support
#
#            A       0.49      0.61      0.54      2694
#            B       0.43      0.52      0.47      2612
#            C       0.71      0.42      0.53      1614
#            D       0.43      0.33      0.37       907
#            E       0.00      0.00      0.00       241
#            F       0.00      0.00      0.00        60
#            G       0.00      0.00      0.00        16
#
#     accuracy                           0.49      8144
#    macro avg       0.29      0.27      0.27      8144
# weighted avg       0.49      0.49      0.48      8144

# %%
print("직접 값을 보고 이상치를 제거했는데, 성능이 오히려 소폭 낮아짐...")
# Out:
# 직접 값을 보고 이상치를 제거했는데, 성능이 오히려 소폭 낮아짐...
