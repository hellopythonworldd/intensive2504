# %% [markdown]
# ## 파이캐럿_분류

# %%
import pandas as pd
from pycaret.classification import *
df = pd.read_csv('credit_risk_dataset.csv')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 from pycaret.classification import *
#       3 df = pd.read_csv('credit_risk_dataset.csv')
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pycaret\classification\__init__.py:1
# ----> 1 from pycaret.classification.functional import (
#       2     add_metric,
#       3     automl,
#       4     blend_models,
#       5     calibrate_model,
#       6     check_drift,
#       7     check_fairness,
#       8     compare_models,
#       9     convert_model,
#      10     create_api,
#      11     create_app,
#      12     create_docker,
#      13     create_model,
#      14     dashboard,
#      15     deploy_model,
#      16     ensemble_model,
#      17     evaluate_model,
#      18     finalize_model,
#      19     get_allowed_engines,
#      20     get_config,
#      21     get_current_experiment,
#      22     get_engine,
#      23     get_leaderboard,
#      24     get_logs,
#      25     get_metrics,
#      26     interpret_model,
#      27     load_experiment,
#      28     load_model,
#      29     models,
#      30     optimize_threshold,
#      31     plot_model,
#      32     predict_model,
#      33     pull,
#      34     remove_metric,
#      35     save_experiment,
#      36     save_model,
#      37     set_config,
#      38     set_current_experiment,
#      39     setup,
#      40     stack_models,
#      41     tune_model,
#      42 )
#      43 from pycaret.classification.oop import ClassificationExperiment
#      45 __all__ = [
#      46     "ClassificationExperiment",
#      47     "setup",
#    (...)     86     "check_drift",
#      87 ]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pycaret\classification\functional.py:8
#       5 import pandas as pd
#       6 from joblib.memory import Memory
# ----> 8 from pycaret.classification.oop import ClassificationExperiment
#       9 from pycaret.internal.parallel.parallel_backend import ParallelBackend
#      10 from pycaret.loggers.base_logger import BaseLogger
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pycaret\classification\oop.py:17
#      14 from scipy.optimize import shgo
#      16 from pycaret.containers.metrics.classification import get_all_metric_containers
# ---> 17 from pycaret.containers.models.classification import (
#      18     ALL_ALLOWED_ENGINES,
#      19     get_all_model_containers,
#      20     get_container_default_engines,
#      21 )
#      22 from pycaret.internal.display import CommonDisplay
#      23 from pycaret.internal.logging import get_logger
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pycaret\containers\models\classification.py:19
#      17 import pycaret.containers.base_container
#      18 import pycaret.internal.cuml_wrappers
# ---> 19 from pycaret.containers.models.base_model import (
#      20     ModelContainer,
#      21     leftover_parameters_to_categorical_distributions,
#      22 )
#      23 from pycaret.internal.cuml_wrappers import get_svc_classifier
#      24 from pycaret.internal.distributions import (
#      25     Distribution,
#      26     IntUniformDistribution,
#      27     UniformDistribution,
#      28 )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pycaret\containers\models\base_model.py:9
#       7 from pycaret.containers.base_container import BaseContainer
#       8 from pycaret.internal.distributions import CategoricalDistribution
# ----> 9 from pycaret.internal.pycaret_experiment.pycaret_experiment import _PyCaretExperiment
#      10 from pycaret.utils.generic import get_allowed_engines, get_logger
#      13 class ModelContainer(BaseContainer):
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pycaret\internal\pycaret_experiment\pycaret_experiment.py:10
#       7 import cloudpickle
#       8 import pandas as pd
# ---> 10 import pycaret.internal.patches.sklearn
#      11 import pycaret.internal.patches.yellowbrick
#      12 import pycaret.internal.persistence
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pycaret\internal\patches\sklearn.py:9
#       6 from sklearn.model_selection._validation import _fit_and_score, _score
#       7 from sklearn.utils import check_random_state
# ----> 9 from pycaret.internal.pipeline import pipeline_predict_inverse_only
#      11 # Monkey patching sklearn.model_selection._search to avoid overflows on windows.
#      12
#      13
#      14 # adapted from https://github.com/scikit-learn/scikit-learn/blob/master/sklearn/utils/_random.pyx
#      15 def _mp_sample_without_replacement(
#      16     n_population: int, n_samples: int, method=None, random_state=None
#      17 ) -> Any:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pycaret\internal\pipeline.py:16
#      13 from copy import deepcopy
#      14 from inspect import signature
# ---> 16 import imblearn.pipeline
#      17 import sklearn.pipeline
#      18 from sklearn.base import clone
#
# File ~\AppData\Roaming\Python\Python311\site-packages\imblearn\__init__.py:54
#      50     sys.stderr.write("Partial import of imblearn during the build process.\n")
#      51     # We are not importing the rest of scikit-learn during the build
#      52     # process, as it may not be compiled yet
#      53 else:
# ---> 54     from . import (
#      55         combine,
#      56         ensemble,
#      57         exceptions,
#      58         metrics,
#      59         model_selection,
#      60         over_sampling,
#      61         pipeline,
#      62         tensorflow,
#      63         under_sampling,
#      64         utils,
#      65     )
#      66     from ._version import __version__
#      67     from .base import FunctionSampler
#
# File ~\AppData\Roaming\Python\Python311\site-packages\imblearn\combine\__init__.py:5
#       1 """The :mod:`imblearn.combine` provides methods which combine
#       2 over-sampling and under-sampling.
#       3 """
# ----> 5 from ._smote_enn import SMOTEENN
#       6 from ._smote_tomek import SMOTETomek
#       8 __all__ = ["SMOTEENN", "SMOTETomek"]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\imblearn\combine\_smote_enn.py:12
#       9 from sklearn.base import clone
#      10 from sklearn.utils import check_X_y
# ---> 12 from ..base import BaseSampler
#      13 from ..over_sampling import SMOTE
#      14 from ..over_sampling.base import BaseOverSampler
#
# File ~\AppData\Roaming\Python\Python311\site-packages\imblearn\base.py:15
#      12 from sklearn.utils._metadata_requests import METHODS
#      13 from sklearn.utils.multiclass import check_classification_targets
# ---> 15 from .utils import check_sampling_strategy, check_target_type
#      16 from .utils._sklearn_compat import _fit_context, get_tags, validate_data
#      17 from .utils._validation import ArraysTransformer
#
# File ~\AppData\Roaming\Python\Python311\site-packages\imblearn\utils\__init__.py:6
#       1 """
#       2 The :mod:`imblearn.utils` module includes various utilities.
#       3 """
#       5 from ._docstring import Substitution
# ----> 6 from ._validation import (
#       7     check_neighbors_object,
#       8     check_sampling_strategy,
#       9     check_target_type,
#      10 )
#      12 __all__ = [
#      13     "check_neighbors_object",
#      14     "check_sampling_strategy",
#      15     "check_target_type",
#      16     "Substitution",
#      17 ]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\imblearn\utils\_validation.py:15
#      13 from scipy.sparse import issparse
#      14 from sklearn.base import clone
# ---> 15 from sklearn.neighbors import NearestNeighbors
#      16 from sklearn.utils import column_or_1d
#      17 from sklearn.utils.multiclass import type_of_target
#
# File ~\miniconda3\envs\py3_11_9\Lib\site-packages\sklearn\neighbors\__init__.py:7
#       1 """
#       2 The :mod:`sklearn.neighbors` module implements the k-nearest neighbors
#       3 algorithm.
#       4 """
#       6 from ._ball_tree import BallTree
# ----> 7 from ._base import VALID_METRICS, VALID_METRICS_SPARSE, sort_graph_by_row_values
#       8 from ._classification import KNeighborsClassifier, RadiusNeighborsClassifier
#       9 from ._graph import (
#      10     KNeighborsTransformer,
#      11     RadiusNeighborsTransformer,
#      12     kneighbors_graph,
#      13     radius_neighbors_graph,
#      14 )
#
# File ~\miniconda3\envs\py3_11_9\Lib\site-packages\sklearn\neighbors\_base.py:28
#      23 from ..metrics._pairwise_distances_reduction import (
#      24     ArgKmin,
#      25     RadiusNeighbors,
#      26 )
#      27 from ..metrics.pairwise import PAIRWISE_DISTANCE_FUNCTIONS
# ---> 28 from ..utils import (
#      29     _to_object_array,
#      30     check_array,
#      31     gen_even_slices,
#      32 )
#      33 from ..utils._param_validation import Interval, StrOptions, validate_params
#      34 from ..utils.fixes import parse_version, sp_base_version
#
# ImportError: cannot import name '_to_object_array' from 'sklearn.utils' (C:\Users\User\miniconda3\envs\py3_11_9\Lib\site-packages\sklearn\utils\__init__.py)

# %%
df = df.drop('loan_int_rate', axis=1)
df.head()

# %%
exp1 = setup(data=df, target='loan_grade', session_id=123)

# %%
best_model = compare_models()

# %%
tuned_model = tune_model(best_model)

# %%
evaluate_model(tuned_model)

# %%
final_model = finalize_model(tuned_model)

# %%
save_model(final_model, 'credit_risk_model')

# %%
loaded_model = load_model('credit_risk_model')

# %%
df.iloc[20:40, 0:-1]

# %%
new_data = df.iloc[20:40, 0:-1]

# %%
predictions = predict_model(loaded_model, data=new_data)

# %%
predictions
