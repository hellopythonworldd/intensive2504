# %% [markdown]
# ## 앙상블학습_에이다부스트회귀

# %%
import pandas as pd

# %%
df = pd.read_csv('house_prices.csv')
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
features = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
       'PTRATIO', 'B', 'LSTAT']

X = df[features]
y = df['MEDV']

# %%
# 트레이닝/테스트 데이터 분할
from sklearn.model_selection import train_test_split
X_tn, X_te, y_tn, y_te = train_test_split(X, y, random_state=0)

# %%
# 트레이닝/테스트 데이터 분할
from sklearn.model_selection import train_test_split
X_tn, X_te, y_tn, y_te = train_test_split(X, y, random_state=0)

# %%
# 데이터 표준화
from sklearn.preprocessing import StandardScaler
std_scale = StandardScaler()
std_scale.fit(X_tn)
X_tn_std = std_scale.transform(X_tn)
X_te_std = std_scale.transform(X_te)

# %%
# 에이다 부스트 학습
from sklearn.ensemble import AdaBoostRegressor
clf_ada = AdaBoostRegressor(random_state=0)
clf_ada.fit(X_tn_std, y_tn)
# Out:
# AdaBoostRegressor(random_state=0)

# %%
ada_pred = clf_ada.predict(X_te_std)
print(ada_pred)
# Out:
# [26.35       23.11636364 23.52916667 11.89384615 19.80540541 23.69934211
#  21.4972973  24.38522727 19.80540541 22.19166667 10.646875   12.85
#  15.32564103 10.78035714 46.03448276 32.96235294 21.4972973  33.45555556
#  26.35       23.69934211 24.66363636 19.57037037 19.14354839 27.02346939
#  22.75       15.77391304 19.11111111 15.77391304 42.8        18.26162791
#  15.45625    17.97017544 22.46703297 20.06266667 24.925625   15.77391304
#  10.78035714 24.38522727 16.76521739 16.76521739 23.97950311 21.4972973
#  25.07755102 17.04       25.07755102 26.9751773  18.57787611 16.47
#  13.3        25.07755102 16.83777778 18.19411765 21.4972973  38.56769231
#  16.76521739 18.26162791 19.57037037 19.57037037 20.06266667 18.46
#  24.440625   19.5175     31.45208333 28.66428571 18.19538462 27.59022989
#  15.78431373 18.19411765 13.40789474 22.46703297 19.5175     24.42871287
#  27.02346939 30.41984733 25.86909091 10.82765957 43.03636364 22.94193548
#  25.07755102 19.57037037 26.35       16.06       16.06       44.41764706
#  41.86454545 24.66363636 23.69934211 16.76521739 25.9        15.78431373
#  18.65703704 11.89384615 25.04882353 28.66428571 23.96140351 23.52916667
#  11.175      25.73780488 15.78431373 19.57037037 24.440625   19.14354839
#  27.59022989 22.19166667 25.07755102 19.57037037 11.175      17.29189189
#  23.69934211 24.57444444 31.45208333 11.75285714 18.19538462 18.53571429
#  18.11538462 19.11111111 11.19487179 21.4972973  11.175      44.70963855
#  29.75864662 10.82765957 18.74       19.80540541 22.5096     18.26162791
#  32.85851064]

# %%
# 모형 평가-MSE
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_te, ada_pred)
print(mse)
# Out:
# 25.17393732173523
