# %% [markdown]
# ## 크로스밸리데이션_회귀예측

# %%
import pandas as pd

# %%
df = pd.read_csv('house_prices.csv')
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
features = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
       'PTRATIO', 'B', 'LSTAT']

X = df[features]
y = df['MEDV']

# %%
# 트레이닝/테스트 데이터 분할
from sklearn.model_selection import train_test_split
X_tn, X_te, y_tn, y_te = train_test_split(X, y, random_state=0)

# %%
# 트레이닝/테스트 데이터 분할
from sklearn.model_selection import train_test_split
X_tn, X_te, y_tn, y_te = train_test_split(X, y, random_state=0)

# %%
# 데이터 표준화
from sklearn.preprocessing import StandardScaler
std_scale = StandardScaler()
std_scale.fit(X_tn)
X_tn_std = std_scale.transform(X_tn)
X_te_std = std_scale.transform(X_te)

# %%
# 그리드 서치 학습
from sklearn import svm
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV

param_grid= {'kernel': ('linear', 'rbf'), 'C': [0.5, 1, 10, 100]}
kfold = KFold(n_splits=5, shuffle=True, random_state=0)
svr = svm.SVR()
grid_cv = GridSearchCV(svr, param_grid, cv=kfold, scoring='neg_mean_squared_error')
grid_cv.fit(X_tn_std, y_tn)
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=0, shuffle=True),
#              estimator=SVR(),
#              param_grid={'C': [0.5, 1, 10, 100], 'kernel': ('linear', 'rbf')},
#              scoring='neg_mean_squared_error')

# %%
# 그리드 서치 결과 학인(데이터프레임)
import numpy as np
import pandas as pd

np.transpose (pd.DataFrame(grid_cv.cv_results_))
# Out:
#                                                 0  \
# mean_fit_time                            0.004331
# std_fit_time                             0.006124
# mean_score_time                          0.000203
# std_score_time                           0.000406
# param_C                                       0.5
# param_kernel                               linear
# params             {'C': 0.5, 'kernel': 'linear'}
# split0_test_score                      -17.445032
# split1_test_score                      -18.593747
# split2_test_score                      -40.571874
# split3_test_score                      -23.262262
# split4_test_score                      -17.088043
# mean_test_score                        -23.392191
# std_test_score                           8.868985
# rank_test_score                                 6
#
#                                              1                             2  \
# mean_fit_time                         0.001812                      0.003893
# std_fit_time                          0.000998                      0.000219
# mean_score_time                        0.00232                      0.000789
# std_score_time                        0.001807                      0.000396
# param_C                                    0.5                           1.0
# param_kernel                               rbf                        linear
# params             {'C': 0.5, 'kernel': 'rbf'}  {'C': 1, 'kernel': 'linear'}
# split0_test_score                    -36.17043                    -17.386875
# split1_test_score                   -16.916761                    -18.521081
# split2_test_score                   -76.712963                    -38.982199
# split3_test_score                   -34.792208                    -23.221267
# split4_test_score                   -33.352135                     -17.18929
# mean_test_score                     -39.588899                    -23.060142
# std_test_score                        19.82833                      8.255832
# rank_test_score                              8                             5
#
#                                            3                              4  \
# mean_fit_time                        0.00257                       0.012767
# std_fit_time                        0.000434                       0.003364
# mean_score_time                     0.001214                         0.0006
# std_score_time                      0.000399                        0.00049
# param_C                                  1.0                           10.0
# param_kernel                             rbf                         linear
# params             {'C': 1, 'kernel': 'rbf'}  {'C': 10, 'kernel': 'linear'}
# split0_test_score                 -27.228367                     -17.458346
# split1_test_score                 -11.816775                     -18.665759
# split2_test_score                 -57.052392                     -37.459318
# split3_test_score                 -24.185331                     -23.007632
# split4_test_score                 -23.301751                     -17.192183
# mean_test_score                   -28.716923                     -22.756648
# std_test_score                     15.103569                       7.642017
# rank_test_score                            7                              4
#
#                                             5                               6  \
# mean_fit_time                        0.004005                         0.07877
# std_fit_time                         0.000004                        0.028485
# mean_score_time                      0.001196                          0.0006
# std_score_time                       0.000401                         0.00049
# param_C                                  10.0                           100.0
# param_kernel                              rbf                          linear
# params             {'C': 10, 'kernel': 'rbf'}  {'C': 100, 'kernel': 'linear'}
# split0_test_score                  -17.409092                      -17.446742
# split1_test_score                   -5.996846                      -18.667153
# split2_test_score                  -26.609204                      -37.063074
# split3_test_score                   -9.182264                      -22.978231
# split4_test_score                    -9.34963                       -17.19154
# mean_test_score                    -13.709407                      -22.669348
# std_test_score                       7.470993                        7.490986
# rank_test_score                             2                               3
#
#                                              7
# mean_fit_time                         0.011089
# std_fit_time                          0.006544
# mean_score_time                         0.0002
# std_score_time                          0.0004
# param_C                                  100.0
# param_kernel                               rbf
# params             {'C': 100, 'kernel': 'rbf'}
# split0_test_score                   -12.562522
# split1_test_score                    -9.235812
# split2_test_score                   -15.662599
# split3_test_score                    -6.061032
# split4_test_score                    -7.405381
# mean_test_score                     -10.185469
# std_test_score                        3.501173
# rank_test_score                              1

# %%
#베스트 스코어
grid_cv.best_score_
# Out:
# np.float64(-10.185469344281099)

# %%
# 베스트 하이퍼파라미터
grid_cv.best_params_
# Out:
# {'C': 100, 'kernel': 'rbf'}

# %%
# 최종 모형
model = grid_cv.best_estimator_
print(model)
# Out:
# SVR(C=100)

# %%
# 예측
pred_svm = model.predict(X_te_std)
print(pred_svm)
# Out:
# [22.36813301 22.68383242 24.87514322 10.71088583 20.84027476 19.73537584
#  23.616982   19.95204534 20.95058207 22.88723384 18.0129821  10.34899842
#  14.71816571  5.72642875 47.13543116 31.19225615 23.92516254 36.38402412
#  29.8542525  21.3802061  23.4583459  19.83747957 20.28994301 27.14446529
#  20.76220706 21.44860078 16.90027694 17.73675701 37.75599541 18.56694782
#  14.91270324 17.94677867 20.52063407 19.43864167 25.7174144  20.14369515
#   8.93195075 38.44771099 14.22520407 15.35656196 23.40736529 21.70393827
#  19.03237972 19.01412226 17.91040447 23.52964267 20.54698635 15.76813636
#  15.11317581 22.73652746 19.59564751 25.60790564 22.65165256 41.80916429
#  13.06089324 21.4381144  18.26724671 18.22905612 17.33432454 20.41504864
#  20.43406878 21.52000315 33.69131932 30.77344561 22.17553542 29.88985454
#  15.50819957 19.56480502 14.23453724 23.5303492  20.05641922 21.67942132
#  25.81683564 28.05436569 24.93138848  5.38768931 41.99027384 23.13659018
#  25.26445049 19.85638849 25.85902651 18.52025113 21.19570909 40.22758261
#  39.50535699 23.25809805 23.11672333  9.04790063 29.07346063 15.92449174
#  17.7692644  10.55809886 20.93928292 29.50531868 18.34810984 21.90451147
#  13.87682884 22.65715519 14.40948843 17.64441106 25.43625826 20.05637127
#  27.85093863 21.94276724 26.62056926 19.48153203  8.00579986 20.60553205
#  18.80943103 26.24519072 36.60697544 14.22751894 18.90000887 19.4296116
#  18.1722466  22.39363559  9.30160799 20.30390731 10.76247437 39.146318
#  27.94538529 11.3299963  18.19807972 21.44198543 19.65920916 19.79011231
#  33.99983958]

# %%
# 모형 평가-MSE
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_te, pred_svm)
print(mse)
# Out:
# 17.517111136855807
