# %% [markdown]
# ## 지도학습(2)_의사결정나무회귀

# %%
import pandas as pd
df = pd.read_csv('house_prices.csv')
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
df['MEDV']
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: MEDV, Length: 506, dtype: float64

# %%
df.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
features = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
       'PTRATIO', 'B', 'LSTAT']

X = df[features]
y = df['MEDV']

# %%
# 트레이닝 테스트 데이터 분할
from sklearn.model_selection import train_test_split
X_tn, X_te, y_tn, y_te = train_test_split(X, y, random_state=0)

# %%
# 데이터 표준화
from sklearn.preprocessing import StandardScaler
std_scale = StandardScaler()
std_scale.fit(X_tn)
X_tn_std = std_scale.transform(X_tn)
X_te_std = std_scale.transform(X_te)

# %%
# 의사결정나무 학습
from sklearn.tree import DecisionTreeRegressor
clf_tree = DecisionTreeRegressor(random_state=0)
clf_tree.fit(X_tn_std, y_tn)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
# 예측
tree_pred = clf_tree.predict(X_te_std)
print(tree_pred)
# Out:
# [23.7 25.  22.7 16.3 22.  20.4 20.6 19.  15.3 16.1 10.5 17.9 12.6  8.8
#  50.  37.  21.4 34.9 22.8 19.6 24.7 22.3 20.1 24.7 22.5 10.9 14.5 15.6
#  39.8 18.8 12.1 19.1 25.  22.2 22.  22.6 10.2 22.6 12.1 17.9 23.9 23.2
#  22.  11.7 26.4 19.  22.5 13.6 13.8 27.5 13.1 19.7 24.  35.2 13.9 18.9
#  19.4 17.6 10.9 22.4 20.6 22.5 29.6 22.8 23.2 24.  18.4 18.9 10.4 22.5
#  20.8 22.2 24.1 30.1 25.   8.8 41.7 23.1 22.  24.5 27.1 14.5 21.4 37.6
#  37.6 25.  20.7 13.8 24.4 16.1 16.6 11.8 20.6 30.1 21.1 23.8 10.2 22.9
#  12.7 18.5 24.7 20.1 30.7 24.5 21.  18.9  7.  15.3 23.9 22.  37.  17.9
#  18.9 19.7 18.9 20.8  7.5 19.2 10.2 50.  30.1  6.3 14.4 21.4 25.  20.5
#  36.1]

# %%
# 모형평가 -MSE
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_te, tree_pred)
print(mse)
# Out:
# 27.977480314960626
