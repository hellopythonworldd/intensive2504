# %% [markdown]
# ## 앙상블학습_배깅회귀

# %%
import pandas as pd
df = pd.read_csv('house_prices.csv')

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
df.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
features = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
       'PTRATIO', 'B', 'LSTAT']

X = df[features]
y = df['MEDV']

# %%
# 
from sklearn.model_selection import train_test_split

X_tn, X_te, y_tn, y_te = train_test_split(X, y, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

std_scale = StandardScaler()
std_scale.fit(X_tn)

X_tn_std = std_scale.transform(X_tn)
X_te_std = std_scale.transform(X_te)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import BaggingRegressor

clf_bagging = BaggingRegressor(estimator=LinearRegression(),
                              n_estimators=10,
                              random_state=0)

# clf_bagging = BaggingRegressor(estimator=KNeighborsRegressor(n_neighbors=2),
#                               n_estimators=10,
#                               random_state=0)

clf_bagging.fit(X_tn_std, y_tn)
# Out:
# BaggingRegressor(estimator=LinearRegression(), random_state=0)

# %%
bagging_pred = clf_bagging.predict(X_te_std)
print(bagging_pred)
# Out:
# [25.0839654  23.49822354 29.17397825 12.08729465 21.46905163 19.43166883
#  20.39380641 21.42796764 19.02260945 20.29661509  6.69566058 16.66927105
#  16.72275994  5.43579547 39.85318189 32.04009046 22.36289689 36.00340928
#  31.01138977 23.31689731 24.93695205 23.91375969 20.74290986 30.33030633
#  22.4797699   9.84756167 17.60724527 17.33990094 35.81865272 20.60768851
#  18.09475111 17.41089629 19.44471052 23.48415134 28.83464067 19.1082166
#  11.25008757 24.66127056 17.71100918 15.28932405 26.18821748 20.96526599
#  22.30262203 15.244506   22.66667615 24.96014824 19.65867436 22.32177133
#   8.962272   24.51031875 20.70627125 17.59798985 24.29619703 30.31171754
#  13.35278458 21.29442164 20.49386244 15.34184932 15.03071355 22.24016016
#  17.19048013 21.53378758 32.83231603 31.38218383 17.81148085 32.46548715
#  18.35519206 18.91386047 19.25030885 23.18195667 22.8995116  24.16560076
#  30.22675264 28.57852969 25.80277697  5.19720088 36.85038725 23.84462441
# ...

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_te, bagging_pred)
print(mse)
# Out:
# 29.489296847115252
